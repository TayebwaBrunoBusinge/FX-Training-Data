# %%
import pandas as pd

file = pd.read_csv("GBPJPY/GBPJPY_2019_h1.csv")
file.head(10)
some = file[50:200]

# %%
import plotly.graph_objects as plt

chart = plt.Figure(
    data=[
        plt.Candlestick(
            x=some.index,
            open=some["p_open"],
            high=some["p_high"],
            low=some["p_low"],
            close=some["p_close"],
        )
    ]
)

chart.show()
