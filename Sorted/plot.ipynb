# %%
import pandas as pd

file = pd.read_csv("EU/EURUSD_2019_d1.csv")
file.head(10)
some = file[:200]

# %%
import plotly.graph_objects as plt

chart = plt.Figure(
    data=[
        plt.Candlestick(
            x=some.index,
            open=some["open"],
            high=some["high"],
            low=some["low"],
            close=some["close"],
        )
    ]
)

chart.show()
